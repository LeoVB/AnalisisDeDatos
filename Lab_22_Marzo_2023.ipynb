# %%
print("ejercicio bisiesto")
anio = int(input("Ingrese el anio: "))
if(anio % 400 == 0) or (anio % 4 == 0) and (anio % 100 != 0):
  print("El anio es bisiesto")
else:
  print("El anio no es bisiesto")
# Out:
# ejercicio bisiesto
# Ingrese el anio: 2022
# El anio no es bisiesto

# %%
print("Problema #1")
C = -1
I = 0
M = 0
while(C<0) or (I<=0) or (I>=100) or (M<=0):
  print("Introduzca el capital, iteres y el tiempo apropiados")
  C=int(input("Caoital: "))
  I=int(input("Interes: "))
  M=int(input("Tiempo en anios: "))

for i in range(M):
  C=C*(1+I/100)
  print("Anio",i+1,"- Monto", C, "Colones")
# Out:
# Problema #1
# Introduzca el capital, iteres y el tiempo apropiados
# Caoital: 1000
# Interes: 10
# Tiempo en anios: 20
# Anio 1 - Monto 1100.0 Colones
# Anio 2 - Monto 1210.0 Colones
# Anio 3 - Monto 1331.0 Colones
# Anio 4 - Monto 1464.1000000000001 Colones
# Anio 5 - Monto 1610.5100000000002 Colones
# Anio 6 - Monto 1771.5610000000004 Colones
# Anio 7 - Monto 1948.7171000000005 Colones
# Anio 8 - Monto 2143.5888100000006 Colones
# Anio 9 - Monto 2357.9476910000008 Colones
# Anio 10 - Monto 2593.742460100001 Colones
# Anio 11 - Monto 2853.1167061100014 Colones
# Anio 12 - Monto 3138.4283767210018 Colones
# Anio 13 - Monto 3452.271214393102 Colones
# Anio 14 - Monto 3797.4983358324125 Colones
# Anio 15 - Monto 4177.248169415654 Colones
# Anio 16 - Monto 4594.97298635722 Colones
# Anio 17 - Monto 5054.470284992943 Colones
# Anio 18 - Monto 5559.917313492238 Colones
# Anio 19 - Monto 6115.909044841462 Colones
# Anio 20 - Monto 6727.499949325608 Colones

# %%
print("Digite un numero")
numero=int(input("numero: "))

while numero>0:
  suma=0
  for i in range(1,numero+1):
    if(numero % i == 0):
      suma=suma+i
  print(suma)
  numero=int(input("Numero: "))
# Out:
# Digite un numero
# numero: 10
# 18
# Numero: 6
# 12
# Numero: 100
# 217
# Numero: 0
