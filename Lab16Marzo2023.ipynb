# %%
#Deco
print("-------------------------------------")
print("Ejem 2: Imrpimer menor de dos números")
print("-------------------------------------")

print("Ingrese 2 números: ")
x = int(input ("Primer numero: "))
y = int(input ("Segundo numero: "))

print("-------------------------------------")
print("\nSalida")

if x > y:
  print("El menor es: ", y)
else:
  print("El menor es: ",x)
# Out:
# -------------------------------------
# Ejem 2: Imrpimer menor de dos números
# -------------------------------------
# Ingrese 2 números:
# Primer numero: 2
# Segundo numero: 7
# -------------------------------------
#
# Salida
# El menor es:  2

# %%
meses = {1:"Enero", 2:"Febrero", 3:"Marzo", 4:"Abril", 5:"Mayo", 6:"Junio", 7:"Julio", 8:"Agosto", 9:"Setiembre", 10:"Octubre", 11:"Noviembre", 12:"Diciembre" }

arg = int(input("Ingrese un número: "))
nameMes = meses.get(arg,"Mes inválido")
print(nameMes)
# Out:
# Ingrese un número: 9
# Setiembre
